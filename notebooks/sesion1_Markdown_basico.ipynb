# %% [markdown]
# <img style="float: left;" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/48/Markdown-mark.svg/208px-Markdown-mark.svg.png" width = 10%> <br>

# %% [markdown]
# # [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# **Es un lenguaje marcado de escritura breve para la publicación de texto en html. Se puede utilizar para la publicación de manera consistente en [internet](https://markdown.es).**
#
# **Existen diferentes versiones de *Markdown* por lo que no hay un estándar. A pesar de esto se darán unos comandos básicos para su uso.**
# ### Comandos, consultar la página del [github](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) para más información
#
# ---
# ---

# %% [markdown]
# # <font color = limegreen>Formato básico:<font>

# %% [markdown]
# ### Cursiva usando `*` y `_` en los extremos de la palabra o frase

# %% [markdown]
# _Saccharomyces cereviciae_ es un hongo unicelular, ...
#
# *Saccharomyces cereviciae* es un hongo unicelular, ...

# %% [markdown]
# ### Negritas usando `**` en los extremos de la palabra o frase

# %% [markdown]
# **_Saccharomyces cereviciae_** es un hongo unicelular, ...

# %% [markdown]
# ### Al final de cada fila agregar `dos espacios` y dar enter para no juntar las líneas
#
# ---
#
# ---

# %% [markdown]
# ### Remarcar una palabra o frase

# %% [markdown]
# Para ver una lista de archivos ejecuta la función `os.listdir()`

# %% [markdown]
# `Para ver una lista de archivos ejecuta la función os.listdir()`
#
# ---
# ---

# %% [markdown]
# # <font color = limegreen>Encabezados:<font>

# %% [markdown]
# ```
# # E1
# ## E2
# ### E3
# #### E4
# ##### E5
# ###### E6
# ```

# %% [markdown]
# ### <font color = red>Copia las lineas anteriores en una celda nueva "Markdown" y ejecuta la línea<font>
#
# ---
# ---

# %% [markdown]
# # <font color = limegreen>Listas:<font>

# %% [markdown]
# ### Para crear listas desordenadas utiliza `*` asteriscos, `-` guiones, o `+` símbolo de suma.

# %% [markdown]
# ## Título
# - Subtítulo 1
# - Subtítulo 2
#     - Sub-lemento 1
#     - Sub-lemento 2
#         - Subsub-elemento 1
#         - Subsub-elemento 2

# %% [markdown]
# ### Para crear listas ordenadas debes utilizar la sintaxis de tipo: “número.” `1.`. Al igual que ocurre con las listas desordenadas, también podrás anidarlas o combinarlas.

# %% [markdown]
# ## Título
# 1. Elemento de lista 1
# 2. Elemento de lista 2
#     - Elemento de lista 3
#     - Elemento de lista 4
#         1. Elemento de lista 5
#         2. Elemento de lista 6
# 3. Continúa con el elemento 3
# 4. Elemento de lista 4
#
# ---
# ---

# %% [markdown]
# Se pueden mezclar distintos tipos de listas y anidar unas dentro de otras.
#
# 1. Esto es una lista ordenada
# 2. Segundo elemento de la lista ordenada
#     1. Esta es una lista ordenada anidada dentro de otra
#         * Lista desordenada anidada a tercer nivel
#         * Segundo elemento de esta lista
#     2. Este es el segundo elemento de la lista ordenada anidada

# %% [markdown]
# # <font color = red>Ejercicio:<font>
# ## Realiza una lista con la siguiente información extraida de [Brenda DB](https://www.brenda-enzymes.org/)
# https://www.brenda-enzymes.org/ecexplorer.php?browser=1&f[nodes]=132,140&f[action]=open&f[change]=141
#
# ```
# Enzyme Classification
# 1 Oxidoreductases (9634 organisms)
# 2 Transferases (6601 organisms)
# 2.1 Transferring one-carbon groups (1295 organisms)
# 2.2 Transferring aldehyde or ketonic groups (183 organisms)
# 2.3 Acyltransferases (1670 organisms)
# 2.3.1 Transferring groups other than aminoacyl groups (1278 organisms)
# 2.3.1.1 amino-acid N-acetyltransferase (37 organisms)
# 3 Hydrolases (9513 organisms)
# 4 Lyases (5106 organisms)
# 5 Isomerases (2066 organisms)
# 6 Ligases (1540 organisms)
# 7 Translocases (833 organisms)
# ```
# ---
# ---

# %% [markdown]
# # <font color = limegreen>Tablas:<font>

# %% [markdown]
# ```
# |     símbolo de tabulador
# ---   alineación del contenido en las céldas (sin : se alinea a la izquierda)
# ---:  alinear a la derecha
# :---: centrar
# ---:  alinear a la izquierda
# |Columna1|Columna2| Arreglo de nombres de columnas
# |Celda1|Celda2| Contenido de las celdas, debajo de los nombres de las columnas
#
# ```

# %% [markdown]
# |Comandos | acción en Python|
# |---|---|
# |`os.listdir()`| *muestra los nombre de archivos*|
# |`os.getcwd()` | muestra el directorio actual|
# |`os.chdir()`| cambio de directorio|
# |`os.mkdir`| crear un directorio|
# |`os.remove(path)`|remover un archivo|
# |`os.rmdir(path)`| remover un directorio|
# |`os.path.exists()`| saber si un directorio existe|
# |`os.path.getsize(path)`| saber el tamaño del directorio|
#
# ---
# ---

# %% [markdown]
# # <font color = red>Ejercicio:<font>
# ## Realiza una tabla con el siguiente contenido
#
# ### Ir a la sección "child terms" que muestra una tabla con términos descendientes directos de [GO:0034599](https://www.ebi.ac.uk/QuickGO/term/GO:0034599)
# https://www.ebi.ac.uk/QuickGO/term/GO:0034599
#
# ---
# ---

# %% [markdown]
# # <font color = limegreen>Visualización de imágenes:<font>

# %% [markdown]
# ### Desde la red
#
# #### Comando
#
# `<img style="float: left;" src="https://julialang.org/images/waves.gif" width = 30%> <br>`

# %% [markdown]
# ### [python](https://www.python.org/)
# <img style="float: left;" src="https://upload.wikimedia.org/wikipedia/commons/9/95/Saccharomyces_cerevisiae_SEM.jpg" width = 30%> <br>

# %% [markdown]
# ### [python](https://www.python.org/)
# <img style="float: center;" src="https://upload.wikimedia.org/wikipedia/commons/9/95/Saccharomyces_cerevisiae_SEM.jpg" width = 30%> <br>

# %% [markdown]
# ### [python](https://www.python.org/)
# <img style="float: right;" src="https://upload.wikimedia.org/wikipedia/commons/9/95/Saccharomyces_cerevisiae_SEM.jpg" width = 30%>

# %% [markdown]
# ### <font color = purple>Descargar esta imagen para hacer pruebas:</font>
# https://raw.githubusercontent.com/Bioinformatica2020/Anexos/master/jupyter_logo.png
#
# ---
# ---

# %% [markdown]
# ### Desde mi ordenador
#
# #### Comando
#
# `![title](jupyter_logo.png)`

# %% [markdown]
# ![Jupyter](C:\Users\pGEN1\Documents\TPP_fosfo_6\resultados\PHOSPHO\imgtesis\GLOBAL_KEGG_Functional_hierarchies2.png)

# %% [markdown]
# ![title](jupyter_logo.png)

# %% [markdown]
# ### Otra opción usando el módulo IPython

# %%
from IPython.core.display import Image, display
display(Image('descargas/bio.jpg', width=300, unconfined=True))

# %% [markdown]
# # <font color = red>Ejercicio:<font/>
# ### Muestra la vista previa de alguna o algunas imágenes de tu interés
#
# ---
# ---
